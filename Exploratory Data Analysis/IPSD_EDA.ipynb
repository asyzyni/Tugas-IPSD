# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/asyzyni/Documents/COLLEGE👩🏻‍🏫/Datasets/medical students data.csv")

# %%
df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
#         Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0               NaN        95.0           109.0        203.0       No     NaN
# 1         98.714977        93.0           104.0        163.0       No      No
# 2         98.260293        76.0           130.0        216.0      Yes      No
# 3         98.839605        99.0           112.0        141.0       No     Yes
# 4         98.480008        95.0             NaN        231.0       No      No
# ...             ...         ...             ...          ...      ...     ...
# 199995    99.170685        65.0           121.0        130.0       No      No
# 199996    97.865785        62.0           125.0        198.0       No     Yes
# 199997    98.768210        60.0            90.0        154.0      NaN      No
# 199998    98.994212        61.0           106.0        225.0       No      No
# 199999    98.595817        95.0           133.0        132.0      NaN      No
#
# [200000 rows x 13 columns]

# %% [markdown]
# ## basic information

# %%
df.head()
# Out:
#    Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1         2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2         3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3         NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4         5.0  23.0  Female         NaN  46.234173          O        NaN
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No     NaN
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No

# %%
df.tail()
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
#         Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 199995    99.170685        65.0           121.0        130.0       No      No
# 199996    97.865785        62.0           125.0        198.0       No     Yes
# 199997    98.768210        60.0            90.0        154.0      NaN      No
# 199998    98.994212        61.0           106.0        225.0       No      No
# 199999    98.595817        95.0           133.0        132.0      NaN      No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB

# %%
df.shape
# Out:
# (200000, 13)

# %%
df.describe()
# Out:
#           Student ID            Age         Height         Weight  \
# count  180000.000000  180000.000000  180000.000000  180000.000000
# mean    49974.042078      26.021561     174.947103      69.971585
# std     28879.641657       4.890528      14.447560      17.322574
# min         1.000000      18.000000     150.000041      40.000578
# 25%     24971.750000      22.000000     162.476110      54.969838
# 50%     49943.500000      26.000000     174.899914      69.979384
# 75%     74986.000000      30.000000     187.464417      84.980097
# max    100000.000000      34.000000     199.998639      99.999907
#
#                  BMI    Temperature     Heart Rate  Blood Pressure  \
# count  180000.000000  180000.000000  180000.000000   180000.000000
# mean       23.338869      98.600948      79.503767      114.558033
# std         7.033554       0.500530      11.540755       14.403353
# min        10.074837      96.397835      60.000000       90.000000
# 25%        17.858396      98.264750      70.000000      102.000000
# 50%        22.671401      98.599654      80.000000      115.000000
# 75%        27.997487      98.940543      90.000000      127.000000
# max        44.355113     100.824857      99.000000      139.000000
#
#          Cholesterol
# count  180000.000000
# mean      184.486361
# std        37.559678
# min       120.000000
# 25%       152.000000
# 50%       184.000000
# 75%       217.000000
# max       249.000000

# %% [markdown]
# ## handling missing val

# %%
df.isnull().sum()
# Out:
# Student ID        20000
# Age               20000
# Gender            20000
# Height            20000
# Weight            20000
# Blood Type        20000
# BMI               20000
# Temperature       20000
# Heart Rate        20000
# Blood Pressure    20000
# Cholesterol       20000
# Diabetes          20000
# Smoking           20000
# dtype: int64

# %%
df = df.dropna(subset=['Student ID'])

# %%
df.isnull().sum()
# Out:
# Student ID            0
# Age               18053
# Gender            17999
# Height            18028
# Weight            18013
# Blood Type        18037
# BMI               17986
# Temperature       17975
# Heart Rate        18039
# Blood Pressure    17984
# Cholesterol       18014
# Diabetes          17923
# Smoking           18012
# dtype: int64

# %% [markdown]
# ## filling missing values

# %% [markdown]
# ### menggunakan modus

# %%
df_new = df.copy() # buat salinan dari df agar tetap aman saat di modifikasi 


# Yang menggunakan Modus, karena tipe datanya object

## Gender
mode_gender = df['Gender'].mode()[0] # ambil nilai modus pada kolom gender
df_new['Gender'] = df['Gender'].fillna(mode_gender)

## Blood Type 
mode_blood = df['Blood Type'].mode()[0] 
df_new['Blood Type'] = df['Blood Type'].fillna(mode_blood)

## Smoking 
mode_smoke = df['Smoking'].mode()[0]
df_new['Smoking'] = df['Smoking'].fillna(mode_smoke)

## Cholesterol
mode_chol = df['Cholesterol'].mode()[0]
df_new['Cholesterol'] = df['Cholesterol'].fillna(mode_chol)

## diabetes 
mode_diabet = df['Diabetes'].mode()[0]
df_new['Diabetes']= df['Diabetes'].fillna(mode_diabet)

# %% [markdown]
# ### menggunakan modus/median

# %% [markdown]
# #### cek distribusi dan outliers

# %%
# mengecek distribusi dan outliers 

## outliers 
df_numerical = df_new[['Age', 'Height', 'Weight', 'BMI', 'Temperature', 'Heart Rate', 'Blood Pressure']]

# Flag untuk melacak apakah ada outliers
outliers_found = False

# Loop untuk memeriksa setiap kolom
for col in df_numerical:
    Q1 = df_new[col].quantile(0.25)  # Kuartil pertama
    Q3 = df_new[col].quantile(0.75)  # Kuartil ketiga
    IQR = Q3 - Q1  # Rentang Interkuartil
    
    # Tentukan batas bawah dan atas untuk outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Deteksi outliers
    outliers = df_new[(df_new[col] < lower_bound) | (df_new[col] > upper_bound)]
    
    if not outliers.empty:  # Jika ada outliers
        print(f"Outliers ditemukan di kolom {col}")
        outliers_found = True

# Jika tidak ada outliers di semua kolom
if not outliers_found:
    print("Tidak ada outliers yang ditemukan di kolom-kolom yang diperiksa.")
# Out:
# Outliers ditemukan di kolom BMI
# Outliers ditemukan di kolom Temperature

# %%
not_outlier = df_new[['Age', 'Height', 'Weight', 'Heart Rate', 'Blood Pressure']]
df_outlier = df_new[['BMI', 'Temperature']]

## untuk not_outlier 
for col in not_outlier.select_dtypes(include=['float64', 'int64']).columns:
    mean_val = not_outlier[col].mean()  # Menghitung rata-rata (mean)
    
    # Mengisi missing values dengan mean ke df_new
    df_new[col] = df_new[col].fillna(mean_val)

## untuk outlier 
for column in df_outlier.select_dtypes(include=['float64', 'int64']).columns:
    median_val = df_outlier[column].median() # mencari median 
    df_new[column] = df_new[column].fillna(median_val) #mengisi missing values

# %%
df_new.isnull().sum()
# Out:
# Student ID        0
# Age               0
# Gender            0
# Height            0
# Weight            0
# Blood Type        0
# BMI               0
# Temperature       0
# Heart Rate        0
# Blood Pressure    0
# Cholesterol       0
# Diabetes          0
# Smoking           0
# dtype: int64

# %% [markdown]
# ## Transformasi Data

# %%
df_new['Height'] = df_new['Height'].round(0).astype(float)
df_new['Weight'] = df_new['Weight'].round(0).astype(float)
df_new['Cholesterol'] = df_new['Cholesterol'].round(0).astype(float)
df_new['Heart Rate'] = df_new['Heart Rate'].round(0).astype(float)

# %% [markdown]
# ## Visualisasi Data

# %% [markdown]
# ### Boxplot

# %%
#hapus Student ID terlebih dahulu
df_graphics = df_new[['Age', 'Height', 'Weight', 'BMI', 'Temperature', 'Heart Rate', 'Blood Pressure', 'Cholesterol']]

plt.figure(figsize=(15, 8))

# Membuat boxplot untuk setiap kolom numerik
for i, col in enumerate(df_graphics.select_dtypes(include=['float64', 'int64']).columns):
    plt.subplot(1, len(df_graphics.select_dtypes(include=['float64', 'int64']).columns), i + 1)
    plt.boxplot(df_graphics[col])  # Mengabaikan nilai NaN
    plt.title(col)
    plt.xlabel("Nilai")
    
plt.suptitle("Boxplot untuk Semua Kolom Numerik", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
#  ### Korelasi beserta heatmap

# %%
correlation = df_graphics.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot = True, annot_kws ={'size' : 10}, cmap = 'coolwarm', cbar=True, fmt='.2f', square=False)
plt.show()

# %%
correlation
# Out:
#                      Age    Height    Weight       BMI  Temperature  \
# Age             1.000000  0.001065  0.004243  0.002763     0.002082
# Height          0.001065  1.000000 -0.001590 -0.497117    -0.003470
# Weight          0.004243 -0.001590  1.000000  0.738606     0.000483
# BMI             0.002763 -0.497117  0.738606  1.000000     0.000695
# Temperature     0.002082 -0.003470  0.000483  0.000695     1.000000
# Heart Rate      0.003841  0.004862 -0.001017 -0.002536    -0.003738
# Blood Pressure -0.004245  0.002488  0.002415  0.000509    -0.002615
# Cholesterol    -0.000653  0.001268 -0.002748 -0.003588     0.000720
#
#                 Heart Rate  Blood Pressure  Cholesterol
# Age               0.003841       -0.004245    -0.000653
# Height            0.004862        0.002488     0.001268
# Weight           -0.001017        0.002415    -0.002748
# BMI              -0.002536        0.000509    -0.003588
# Temperature      -0.003738       -0.002615     0.000720
# Heart Rate        1.000000        0.002513     0.006155
# Blood Pressure    0.002513        1.000000     0.002099
# Cholesterol       0.006155        0.002099     1.000000

# %% [markdown]
# ## Unique Values ##

# %%
#nilai unik
unique_counts = {} #buat dictionary kosong untuk menaruh hasil iterasi

for column in df_new.columns: #looping untuk mengecek semua kolom pada df
    unique_count = df_new[column].nunique() #digunakan untuk mengecek nilai unik di setiap kolom df
    unique_counts[column] = unique_count 

persebaran_uniq_df = pd.DataFrame(list(unique_counts.items()), columns = ['Kolom', 'Nilai Unik']) #untuk mengubah dictionary unique_counts menjadi dataframe

print("persebaran nilai unik : ")
persebaran_uniq_df
# Out:
# persebaran nilai unik :
#              Kolom  Nilai Unik
# 0       Student ID       98976
# 1              Age          18
# 2           Gender           2
# 3           Height          51
# 4           Weight          61
# 5       Blood Type           4
# 6              BMI       96367
# 7      Temperature       96289
# 8       Heart Rate          40
# 9   Blood Pressure          51
# 10     Cholesterol         130
# 11        Diabetes           2
# 12         Smoking           2

# %%
for_uniqval = df_new.drop(columns=['Student ID', 'Weight', 'Height', 'Temperature', 'BMI', 'Cholesterol', 'Blood Pressure'])

for col in for_uniqval.columns:
    plt.figure(figsize=(10, 6))
    unique_counts = for_uniqval[col].value_counts(dropna=False)  # Counting NaN values as well
    sns.barplot(x=unique_counts.index.astype(str), y=unique_counts.values)
    plt.xticks(rotation=45)
    plt.title(f'Unique Values and Counts in {col}')
    plt.ylabel('Count')
    plt.xlabel(col)
    plt.savefig(f'{col}_unique_values_plot.png', bbox_inches='tight')
    plt.show()
